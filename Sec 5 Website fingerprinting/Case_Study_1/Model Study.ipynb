# %%
from keras.models import load_model
model = load_model('cnn_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 996, 64)        │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 498, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 496, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 248, 128)       │             0 │
# ...

# %%
for layer in model.layers:
    print(f"Layer: {layer.name}")
    for weight_tensor in layer.weights:
        print(f"  {weight_tensor.name} - shape: {weight_tensor.shape}")
        print(weight_tensor.numpy())
# Out:
# Layer: conv1d
#   kernel - shape: (5, 1, 64)
# [[[ 8.79759714e-02  1.82781979e-01  2.37927940e-02  1.98749483e-01
#    -4.51316535e-02 -5.31613231e-02 -3.10686231e-01 -2.93404043e-01
#     2.95533597e-01 -5.60391545e-02 -2.68306322e-02 -1.06031358e-01
#     1.34029090e-01 -4.99702655e-02  2.45813668e-01  1.32900709e-02
#     2.53594398e-01  4.73774783e-02 -2.43743256e-01  2.89693624e-01
#     2.79517949e-01  2.71622032e-01 -2.02588767e-01 -1.29732676e-02
#     2.85279632e-01 -2.61327267e-01 -1.29381955e-01  1.06917180e-01
#    -2.73434632e-03 -2.92232662e-01  2.90116854e-02  2.46844962e-01
#    -1.46209896e-01 -2.85691112e-01  2.72583812e-01  2.41993412e-01
#    -6.31582439e-02 -1.25849426e-01  2.76908726e-01 -7.71092772e-02
#     1.02489650e-01 -2.71824658e-01 -3.52336317e-02 -4.12329584e-02
#    -2.65817791e-01  2.39026323e-01  1.20022528e-01 -3.66491303e-02
#    -6.58999383e-02  1.06907561e-02  1.04879931e-01  4.02829498e-02
# ...

# %%
conv_layer = model.get_layer('conv1d_1') 
weights, biases = conv_layer.get_weights()
print("Weights shape:", weights.shape)
print("Biases shape:", biases.shape)
print(weights)
# Out:
# Weights shape: (3, 64, 128)
# Biases shape: (128,)
# [[[-0.07616738  0.01213556  0.02655128 ... -0.11371256 -0.15692791
#     0.00115103]
#   [-0.06291489 -0.06471995 -0.08288146 ... -0.1574917  -0.01901865
#    -0.02240956]
#   [-0.07307053 -0.21347305  0.01414927 ...  0.02336113 -0.13775215
#    -0.03977214]
#   ...
#   [-0.0535055  -0.00925212 -0.0508715  ... -0.03658367 -0.06881417
#    -0.12776308]
#   [-0.0792383  -0.13854364 -0.01611829 ...  0.02607145 -0.10207765
#     0.02550684]
#   [ 0.04084711  0.01256915 -0.05240138 ... -0.1343986  -0.11531839
#     0.00099817]]
#
#  [[-0.02535724  0.03502888  0.00476307 ...  0.01156089  0.02070577
#    -0.06543702]
#   [-0.10560822 -0.08026294 -0.00867624 ...  0.01886159 -0.06673175
#    -0.10425237]
#   [-0.01380859  0.02100482 -0.08497071 ...  0.06822307 -0.0700942
#    -0.02964087]
#   ...
#   [-0.00174552  0.06045968  0.02784257 ...  0.01386854 -0.13359809
#     0.03566875]
# ...
